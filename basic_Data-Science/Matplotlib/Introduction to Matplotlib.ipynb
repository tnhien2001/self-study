# %% [markdown]
# # Introduction to Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(); #Dấu ";" giúp xóa dấu []

# %%
plt.style.available #Các kiểu nền của khung plot
plt.style.use('seaborn')

# %%
x = [1, 2, 3, 4]
y = [10, 8 , 6, 9]
plt.plot(x,y, color='red')

# %% [markdown]
# ## Pyplot API vs Object Oriented (OO) API
# * Pyplot API $\rightarrow$ Quickly
# * OO API $\rightarrow$ Advanced
#
# #### Pyplot API

# %%
x = np.linspace(0, 10, 1000)
x
# Out:
# array([ 0.        ,  0.01001001,  0.02002002,  0.03003003,  0.04004004,
#         0.05005005,  0.06006006,  0.07007007,  0.08008008,  0.09009009,
#         0.1001001 ,  0.11011011,  0.12012012,  0.13013013,  0.14014014,
#         0.15015015,  0.16016016,  0.17017017,  0.18018018,  0.19019019,
#         0.2002002 ,  0.21021021,  0.22022022,  0.23023023,  0.24024024,
#         0.25025025,  0.26026026,  0.27027027,  0.28028028,  0.29029029,
#         0.3003003 ,  0.31031031,  0.32032032,  0.33033033,  0.34034034,
#         0.35035035,  0.36036036,  0.37037037,  0.38038038,  0.39039039,
#         0.4004004 ,  0.41041041,  0.42042042,  0.43043043,  0.44044044,
#         0.45045045,  0.46046046,  0.47047047,  0.48048048,  0.49049049,
#         0.5005005 ,  0.51051051,  0.52052052,  0.53053053,  0.54054054,
#         0.55055055,  0.56056056,  0.57057057,  0.58058058,  0.59059059,
#         0.6006006 ,  0.61061061,  0.62062062,  0.63063063,  0.64064064,
# ...

# %%
plt.plot(x, np.sin(x), linestyle="dashed", label='sin(x)');
plt.plot(x, np.cos(x), color='red', linestyle="dashed", label="cos(x)");

plt.title("Sin(x) and Cos(x)")
plt.xlabel('x')
plt.ylabel('Sin(x)')

# plt.xlim([0,4])
# plt.ylim([1, -0.75])
# plt.axis([0,4, -0.7, 0.6]) # tương đương xlim và ylim
# plt.axis("equal")
plt.axis('tight')

plt.legend(); #Chỉ dùng đc khi vẽ có label ở dòng plot()

# %% [markdown]
# #### Object-Oriented API

# %%
#1. Prepare Data
x = [1,2,3,4]
y = [11,22,33,44]

#2. Setup plot
fig, ax = plt.subplots(figsize=(5,5)) #Figure size = Width & Height of the plot

#3. Plot the Data
ax.plot(x,y);

ax.set(title='A simple plot',
      xlabel='x-axis', ylabel='y-axis'
      )
# Out:
# [Text(0.5, 1.0, 'A simple plot'),
#  Text(0.5, 0, 'x-axis'),
#  Text(0, 0.5, 'y-axis')]

# %% [markdown]
# ## 2. Most common types of Matplotlib plots
# * Line
# * Scatter
# * Bar
# * Hist
# * Subplots
#
# ### 1. Line

# %%
# Create an array
x = np.linspace(0,10, 100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
#OO API plot a line chart

fig, ax = plt.subplots()
ax.plot(x, x**3);

# %% [markdown]
# ### 2. Scatter

# %%
#Pyplot API
plt.scatter(x, np.exp(x)) # y = e^(x)

# %%
# OO API

#Prepare New Data
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)

colors = rng.rand(100)
sizes = 1000*rng.rand(100)

fig, ax = plt.subplots()
img1 = ax.scatter(x,y, s=sizes, c=colors, cmap='viridis', alpha=0.3)

fig.colorbar(img1);

# %% [markdown]
# ### 3. Bar
# * Vertical
# * Horizontal

# %%
# Prepare Data from a python dictionary
soft_drink_prices = {"Coke": 10,
                     "Pepsi": 12,
                     "Sprite": 8}

fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values())
ax.set(title="Tap Hoa's Soft Drink Prices", ylabel="Price($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), soft_drink_prices.values());
ax.set(title="Tap Hoa's Soft Drink Prices", xlabel="Price($)");

# %% [markdown]
# ### 4. Histogram

# %%
#Prepare data
np.random.seed(42)
student_height = np.random.normal(170, 10, 250)

# %%
student_height[:10]
# Out:
# array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#        167.65846625, 167.65863043, 185.79212816, 177.67434729,
#        165.30525614, 175.42560044])

# %%
#Pyplot API
plt.hist(student_height, bins = 30);

# %% [markdown]
# ### Subplots

# %%
# Option 1:
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2,
                       ncols = 2,
                       figsize=(10, 5))

# Plot data to each axis
ax1.plot(x, x/2);
ax1.plot(x, x*2);

ax2.scatter(np.random.random(10), np.random.random(10));

ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values());

ax4.hist(student_height, bins = 30);

# %%
# Option 2:
fig, ax = plt.subplots(2,2, figsize=(10,5))

ax[0][0].plot(x, x/2);
ax[0][0].plot(x, x*2);

ax[0][1].scatter(np.random.random(10), np.random.random(10));

ax[1][0].bar(soft_drink_prices.keys(), soft_drink_prices.values());

ax[1][1].hist(student_height, bins = 30);
